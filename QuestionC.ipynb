# %% [markdown]
# ## Environment Preparation

# %% [markdown]
# ### Import Data First

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np

# %% [markdown]
# ### Time to Read the Data Set

# %%
concrete_data = pd.read_csv("C:/Users/tjame/Downloads/concrete_data.csv")
dataset = concrete_data.values

# %% [markdown]
# # Part B

# %% [markdown]
# ### Normalize the data¶
# Repeat Part A but use a normalized version of the data. Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.

# %%
dataset_norm = []
for i in range(9):
    _mean = np.mean(dataset[:,i])
    _std = np.std(dataset[:,i])
    _norm = (dataset[:,i] - _mean) / _std
    dataset_norm.append(_norm)

# %%
dataset_normalized = np.asarray(dataset_norm).T

# %%
# split the concrete_data set into predictors (inputs) and target (output)
X = dataset_normalized[:,0:7]
Y = dataset_normalized[:,8]

n_cols = X.shape[1]

# %% [markdown]
# # Part A

# %% [markdown]
# ### Use the Keras library to build a neural network with the following:
#
# One hidden layer of 10 nodes, and a ReLU activation function
# Use the adam optimizer and the mean squared error as the loss function.

# %%
# Create the neural network in a function so we can use it multiple times in the
# subsequent sections
def baseline_model():
    # create model
    model = Sequential()
    model.add(Dense(7, input_dim=7, kernel_initializer='normal', activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

model = baseline_model()

# %% [markdown]
# ### Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_split helper function from Scikit-learn.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=71)
# let's have a look at the shape of the predictors set
X_train.shape
# Out:
# (721, 7)

# %% [markdown]
# ### Train the model on the training data using 50 epochs.¶

# %%
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 0s 1ms/step - loss: 1.0696
# Epoch 2/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.9069
# Epoch 3/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.9322
# Epoch 4/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.8938
# Epoch 5/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.8014
# Epoch 6/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6795
# Epoch 7/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6023
# Epoch 8/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5862
# Epoch 9/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5677
# Epoch 10/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5522
# Epoch 11/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5562
# Epoch 12/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5202
# ...

# %% [markdown]
# ### Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.

# %%
y_pred = model.predict(X_test)
from sklearn.metrics import mean_squared_error
print('Mean squared error on test data is %.3f' % (mean_squared_error(y_test, y_pred)))
# Out:
# Mean squared error on test data is 0.462

# %% [markdown]
# ### Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors. Report the mean and the standard deviation of the mean squared errors.

# %%
mse = []
for i in range(50):
    model = baseline_model()
    model.fit(X_train, y_train, epochs=50)
    y_pred = model.predict(X_test)
    mse.append(mean_squared_error(y_test, y_pred))
# Out:
# Epoch 1/50
# 23/23 [==============================] - 0s 1ms/step - loss: 1.0780
# Epoch 2/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.9710
# Epoch 3/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.8520
# Epoch 4/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.8340
# Epoch 5/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7431
# Epoch 6/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6856
# Epoch 7/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6023
# Epoch 8/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5568
# Epoch 9/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5517
# Epoch 10/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5639
# Epoch 11/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5853
# Epoch 12/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5357
# ...

# %% [markdown]
# ### Report the mean and the standard deviation of the mean squared errors.

# %%
mean = np.mean(mse)
mean
# Out:
# 0.47148779062006474

# %%
std = np.std(mse)
std
# Out:
# 0.009491135033777447

# %%
print("Mean squared errors for 50 regression models: mean = %.3f, std dev = %.3f" %(mean, std))
# Out:
# Mean squared errors for 50 regression models: mean = 0.471, std dev = 0.009

# %% [markdown]
# # Part C

# %% [markdown]
# ### Increate the number of epochs
#
# Repeat Part B but use 100 epochs this time for training

# %%
mse = []
for i in range(50):
    model = baseline_model()
    model.fit(X_train, y_train, epochs=100)
    y_pred = model.predict(X_test)
    mse.append(mean_squared_error(y_test, y_pred))
# Out:
# Epoch 1/100
# 23/23 [==============================] - 0s 1ms/step - loss: 1.0633
# Epoch 2/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.9285
# Epoch 3/100
# 23/23 [==============================] - 0s 1ms/step - loss: 0.9203
# Epoch 4/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.8925
# Epoch 5/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.8758
# Epoch 6/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7527
# Epoch 7/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7810
# Epoch 8/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7092
# Epoch 9/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7589
# Epoch 10/100
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6918
# Epoch 11/100
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6854
# Epoch 12/100
# ...

# %% [markdown]
# ### Report the mean and the standard deviation of the mean squared errors.

# %%
mean = np.mean(mse)
mean
# Out:
# 0.46607239865995737

# %%
std = np.std(mse)
std
# Out:
# 0.010402444063202867

# %%
print("Mean squared errors for 50 regression models and 100 training epochs: mean = %.3f, std dev = %.3f" %(mean, std))
# Out:
# Mean squared errors for 50 regression models and 100 training epochs: mean = 0.466, std dev = 0.010

# %% [markdown]
# ### How does the mean of the mean squared errors compare to that from Step B?
#
# The mean squared error on the test set decreased more than 50%. Plenty of improvement can be obtained with additional training. The standard deviation has greatly decreased also.
